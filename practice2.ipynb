# %%
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
from scipy import stats

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
data1 = randn(100)
data2 = randn(100)

# %%
sns.boxplot([data1,data2])
# Out:
# <Axes: >

# %%
sns.boxplot([data1,data2],whis=np.inf)
# Out:
# <Axes: >

# %%
sns.boxplot(data1, vert=False)
# Out:
# <Axes: >

# %%
sns.violinplot([data1,data2])
# Out:
# <Axes: >

# %%
sns.violinplot(data2, bw=0.01)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8528\1204880025.py:1: FutureWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method`/`bw_adjust`.
# Setting `bw_method=0.01`, but please see docs for the new parameters
# and update your code. This will become an error in seaborn v0.15.0.
#
#   sns.violinplot(data2, bw=0.01)
# <Axes: >

# %%
#regression plots

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x="total_bill",y="tip",data=tips)

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,
          scatter_kws={"marker":"o","color":"indianred"},
          line_kws={"linewidth":1,"color":"blue"})

# %%
tips["tip_percentage"] = 100*(tips["tip"]/tips["total_bill"])

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_percentage
# 0       16.99  1.01  Female     No  Sun  Dinner     2        5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3       16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3       16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2       13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4       14.680765

# %%
sns.lmplot(x="size",y="tip_percentage",data=tips)

# %%
sns.lmplot(x="total_bill",y="tip_percentage",data=tips,hue="sex",markers=["x","o"])
