# %%
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
from scipy import stats

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 6.,  9., 13., 13., 16., 17.,  5.,  6.,  8.,  7.]),
#  array([-1.95689948, -1.56003502, -1.16317056, -0.7663061 , -0.36944163,
#          0.02742283,  0.42428729,  0.82115175,  1.21801621,  1.61488068,
#          2.01174514]),
#  <BarContainer object of 10 artists>)

# %%
dataset2 = randn(80)

# %%
plt.hist(dataset2,color="indianred")
# Out:
# (array([ 5.,  6.,  8., 16., 15., 15.,  7.,  4.,  3.,  1.]),
#  array([-1.9562295 , -1.53083788, -1.10544625, -0.68005463, -0.25466301,
#          0.17072862,  0.59612024,  1.02151186,  1.44690349,  1.87229511,
#          2.29768673]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(dataset1,color="indianred",alpha=0.5,bins=20)
plt.hist(dataset2,alpha=0.5,bins=20)
# Out:
# (array([3., 2., 3., 3., 2., 6., 7., 9., 8., 7., 8., 7., 2., 5., 1., 3., 2.,
#         1., 0., 1.]),
#  array([-1.9562295 , -1.74353369, -1.53083788, -1.31814206, -1.10544625,
#         -0.89275044, -0.68005463, -0.46735882, -0.25466301, -0.04196719,
#          0.17072862,  0.38342443,  0.59612024,  0.80881605,  1.02151186,
#          1.23420768,  1.44690349,  1.6595993 ,  1.87229511,  2.08499092,
#          2.29768673]),
#  <BarContainer object of 20 artists>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(x=data1,y=data2)

# %%
sns.jointplot(x=data1,y=data2,kind="hex")

# %%
#combining plots

# %%
dataset1 = randn(100)

# %%
sns.distplot(dataset1, bins=20)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10636\4233952527.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset1, bins=20)
# <Axes: ylabel='Density'>

# %%
sns.distplot(dataset1, bins=20,rug=True, hist=False)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10636\3427902916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset1, bins=20,rug=True, hist=False)
# <Axes: ylabel='Density'>

# %%
sns.distplot(dataset1,bins=20,
             kde_kws={"color":"indianred","label":"KDE PLOT"},
             hist_kws={"color":"blue","label":"HIST"} )
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10636\3860306090.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset1,bins=20,
# <Axes: ylabel='Density'>

# %%
from pandas import Series

# %%
ser1 = Series(dataset1,name="my_data")
ser1
# Out:
# 0    -0.668336
# 1     0.709407
# 2    -0.240644
# 3     1.614816
# 4    -0.191945
#         ...
# 95    0.136837
# 96    0.120901
# 97    0.640032
# 98   -0.252927
# 99    1.545114
# Name: my_data, Length: 100, dtype: float64

# %%
sns.distplot(ser1,bins=25)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10636\3093412986.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ser1,bins=25)
# <Axes: xlabel='my_data', ylabel='Density'>
